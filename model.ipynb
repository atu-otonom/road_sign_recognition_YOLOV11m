# %%
# !yolo task=detect mode=train epochs=100 data='/home/shagen/vscode/road-sign/yolov8/data.yaml' model=yolo11m.pt imgsz=640
# Out:
# ...
# 100%|██████████████████████████████████████| 38.8M/38.8M [00:05<00:00, 7.80MB/s]
# New https://pypi.org/project/ultralytics/8.3.74 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.40 🚀 Python-3.12.9 torch-2.6.0+cu126 CUDA:0 (NVIDIA GeForce RTX 3080, 9899MiB)
# ...

# %%
# !yolo task=detect mode=predict model="C:/Users/askin/Desktop/vscode/otonom/road_sign/YOLO/yolo/road_sign_recognition_yolo11.pt" show=True conf=0.5 source=0 project="C:/Users/askin/Desktop/vscode/otonom/road_sign/YOLO/yolo/yolo_results" name="predict_output"
